# %% [markdown]
# # Task 1

# %%
# write code in this box

#rewrite the code on line 4 so that your own name is displayed when the program is executed
name = "Mr Wheeler" 
print(name)
# Out:
# Mr Wheeler

# %% [markdown]
# # Task 2

# %%
# write code in this box

# %% [markdown]
# # Task 3

# %%
#Write code in this box
number1 = "2"
number2 = "2"
answer = number1 + number2
print(answer)
